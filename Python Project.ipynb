# %%
from tkinter import *
from PIL import ImageTk, Image

main = Tk()
    
def ok1():
    ##instruction for first set of images
    global main1
    global box
    global l1
    global bt
    main1=Tk()
    main.destroy()
    
    l1=Label(main1,bg='black',fg='lime green')
    l1.config(text=("Select the name whose image was present in the gallery shown : "))
    l1.pack()
    
    box=Listbox(main1,height=7,selectmode=MULTIPLE)
    box.insert(0,"Computer")
    box.insert(1,"Lion")
    box.insert(2,"Bicycle")
    box.insert(3,"Earth")
    box.insert(4,"Grass")
    box.insert(5,"Door")
    box.insert(6,"Football")
    box.pack()
    
    bt=Button(main1,text='SUBMIT',bg='black',fg='lime green',command=check1)
    bt.pack(side="bottom")

def check1(): 
    user_sel=box.curselection()
    j=len(user_sel)
    global l
    valid=3
    wrong,correct=0,0
    i=0
    while i<j:
        if (user_sel[i]==1):
            correct=correct+1
        elif (user_sel[i]==3):
            correct=correct+1
        elif (user_sel[i]==6):
            correct=correct+1
        else:
            wrong=wrong+1
        i=i+1
    box.destroy()
    l1.config(text=("Detailed Analysis : "))
    l2=Label(main1)
    l2.config(text=("  "))
    l2.pack()
    h1=Label(main1)
    h1.config(text=("Correct Answers Marked : "))
    h1.pack()
    h2=Label(main1)
    h2.config(text=(correct))
    h2.pack()
    h3=Label(main1)
    h3.config(text=("Wrong Answers Marked : "))
    h3.pack()
    h4=Label(main1)
    h4.config(text=(wrong))
    h4.pack()
    h5=Label(main1)
    h5.config(text=("Total valid answers given : "))
    h5.pack()
    h6=Label(main1)
    h6.config(text=(valid))
    h6.pack()
    h7=Label(main1)
    h7.config(text=("Remarks : "))
    h7.pack()
    h8=Label(main1)
    if ((((correct-wrong)*100)/valid)>80):
        h8.config(text=("Excellent"))
    elif ((((correct-wrong)*100)/valid)>49):
        h8.config(text=("Good"))
    elif ((((correct-wrong)*100)/valid)>20):
        h8.config(text=("Average"))
    else:
        h8.config(text=("Seems like you are guessing"))  
    h8.pack()
    h9=Label(main1)
    h9.config(text=("  "))
    h9.pack()
    bt.config(text=("Exit"),command=e1)
    
def e1():
    ##to destroy the window
    main1.destroy() 
    
def ok2():
    ##instruction for second set of images
    global main3
    global box2
    global l2
    global bt2
    main3=Tk()
    main.destroy()
    
    l2=Label(main3,bg='black',fg='lime green')
    l2.config(text=("Select the name whose image was present in the gallery shown : "))
    l2.pack()
    
    box2=Listbox(main3,height=7,selectmode=MULTIPLE)
    box2.insert(0,"Tree")
    box2.insert(1,"Dog")
    box2.insert(2,"Bed")
    box2.insert(3,"Chair")
    box2.insert(4,"Bag")
    box2.insert(5,"Bird")
    box2.insert(6,"Sun")
    box2.pack()
    
    bt2=Button(main3,text='SUBMIT',bg='black',fg='lime green',command=check2)
    bt2.pack(side="bottom")
    
def check2():
    user_sel=box2.curselection()
    j=len(user_sel)
    wrong,correct=0,0
    valid=3
    i=0
    while i<j:
        if (user_sel[i]==0):
            correct=correct+1
        elif (user_sel[i]==4):
            correct=correct+1
        elif (user_sel[i]==5):
            correct=correct+1
        else:
            wrong=wrong+1
        i=i+1
    box2.destroy()
    l2.config(text=("Detailed Analysis : "))
    l1=Label(main3)
    l1.config(text=("  "))
    l1.pack()
    h1=Label(main3)
    h1.config(text=("Correct Answers Marked : "))
    h1.pack()
    h2=Label(main3)
    h2.config(text=(correct))
    h2.pack()
    h3=Label(main3)
    h3.config(text=("Wrong Answers Marked : "))
    h3.pack()
    h4=Label(main3)
    h4.config(text=(wrong))
    h4.pack()
    h5=Label(main3)
    h5.config(text=("Total valid answers given : "))
    h5.pack()
    h6=Label(main3)
    h6.config(text=(valid))
    h6.pack()
    h7=Label(main3)
    h7.config(text=("Remarks : "))
    h7.pack()
    h8=Label(main3)
    if ((((correct-wrong)*100)/valid)>80):
        h8.config(text=("Excellent"))
    elif ((((correct-wrong)*100)/valid)>49):
        h8.config(text=("Good"))
    elif ((((correct-wrong)*100)/valid)>20):
        h8.config(text=("Average"))
    else:
        h8.config(text=("Seems like you are guessing"))  
    h8.pack()
    h9=Label(main3)
    h9.config(text=("  "))
    h9.pack()
    bt2.config(text=("Exit"),command=e2)
    
def e2():
    ##to destroy the window
    main3.destroy()   
    
def ok3():
    ##instruction for third set of images
    global main4
    global box3
    global l3
    global bt3
    main4=Tk()
    main.destroy()
    
    l3=Label(main4,bg='black',fg='lime green')
    l3.config(text=("Select the name whose image was present in the gallery shown : "))
    l3.pack()
    
    box3=Listbox(main4,height=7,selectmode=MULTIPLE)
    box3.insert(0,"Car")
    box3.insert(1,"House")
    box3.insert(2,"Train")
    box3.insert(3,"Mobile")
    box3.insert(4,"Tree")
    box3.insert(5,"Window")
    box3.insert(6,"Chair")
    box3.pack()
    
    bt3=Button(main4,text='SUBMIT',bg='black',fg='lime green',command=check3)
    bt3.pack(side="bottom")
    
def check3():
    user_sel=box3.curselection()
    j=len(user_sel)
    wrong,correct=0,0
    valid=3
    i=0
    while i<j:
        if (user_sel[i]==1):
            correct=correct+1
        elif (user_sel[i]==2):
            correct=correct+1
        elif (user_sel[i]==6):
            correct=correct+1
        else:
            wrong=wrong+1
        i=i+1
    box3.destroy()
    l3.config(text=("Detailed Analysis : "))
    l1=Label(main4)
    l1.config(text=("  "))
    l1.pack()
    h1=Label(main4)
    h1.config(text=("Correct Answers Marked : "))
    h1.pack()
    h2=Label(main4)
    h2.config(text=(correct))
    h2.pack()
    h3=Label(main4)
    h3.config(text=("Wrong Answers Marked : "))
    h3.pack()
    h4=Label(main4)
    h4.config(text=(wrong))
    h4.pack()
    h5=Label(main4)
    h5.config(text=("Total valid answers given : "))
    h5.pack()
    h6=Label(main4)
    h6.config(text=(valid))
    h6.pack()
    h7=Label(main4)
    h7.config(text=("Remarks : "))
    h7.pack()
    h8=Label(main4)
    if ((((correct-wrong)*100)/valid)>80):
        h8.config(text=("Excellent"))
    elif ((((correct-wrong)*100)/valid)>49):
        h8.config(text=("Good"))
    elif ((((correct-wrong)*100)/valid)>20):
        h8.config(text=("Average"))
    else:
        h8.config(text=("Seems like you are guessing"))  
    h8.pack()
    h9=Label(main4)
    h9.config(text=("  "))
    h9.pack()
    bt3.config(text=("Exit"),command=e3)
    
def e3():
    ##to destroy the window
    main4.destroy()   
    
def ok4():
    ##instruction for third set of images
    global main5
    global box4
    global l4
    global bt4
    main5=Tk()
    main.destroy()
    
    l4=Label(main5,bg='black',fg='lime green')
    l4.config(text=("Select the name whose image was present in the gallery shown : "))
    l4.pack()
    
    box4=Listbox(main5,height=7,selectmode=MULTIPLE)
    box4.insert(0,"Dog")
    box4.insert(1,"Car")
    box4.insert(2,"Tree")
    box4.insert(3,"Computer")
    box4.insert(4,"House")
    box4.insert(5,"Fan")
    box4.insert(6,"Telephone")
    box4.pack()
    
    bt4=Button(main5,text='SUBMIT',bg='black',fg='lime green',command=check4)
    bt4.pack(side="bottom")
    
def check4():
    user_sel=box4.curselection()
    j=len(user_sel)
    wrong,correct=0,0
    valid=3
    i=0
    while i<j:
        if (user_sel[i]==0):
            correct=correct+1
        elif (user_sel[i]==3):
            correct=correct+1
        elif (user_sel[i]==6):
            correct=correct+1
        else:
            wrong=wrong+1
        i=i+1
    box4.destroy()
    l4.config(text=("Detailed Analysis : "))
    l1=Label(main5)
    l1.config(text=("  "))
    l1.pack()
    h1=Label(main5)
    h1.config(text=("Correct Answers Marked : "))
    h1.pack()
    h2=Label(main5)
    h2.config(text=(correct))
    h2.pack()
    h3=Label(main5)
    h3.config(text=("Wrong Answers Marked : "))
    h3.pack()
    h4=Label(main5)
    h4.config(text=(wrong))
    h4.pack()
    h5=Label(main5)
    h5.config(text=("Total valid answers given : "))
    h5.pack()
    h6=Label(main5)
    h6.config(text=(valid))
    h6.pack()
    h7=Label(main5)
    h7.config(text=("Remarks : "))
    h7.pack()
    h8=Label(main5)
    if ((((correct-wrong)*100)/valid)>80):
        h8.config(text=("Excellent"))
    elif ((((correct-wrong)*100)/valid)>49):
        h8.config(text=("Good"))
    elif ((((correct-wrong)*100)/valid)>20):
        h8.config(text=("Average"))
    else:
        h8.config(text=("Seems like you are guessing"))  
    h8.pack()
    h9=Label(main5)
    h9.config(text=("  "))
    h9.pack()
    bt4.config(text=("Exit"),command=e4)
    
def e4():
    ##to destroy the window
    main5.destroy()   
    
def ref():
    ##second set of images 
    img6=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\bag.png"))
    panel.config(image=img6)
    panel.image=img6
    
    img7=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\knife.png"))
    panel1.config(image=img7)
    panel1.image=img7
    
    img8=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\bicycle.png"))
    panel2.config(image=img8)
    panel2.image=img8
    
    img9=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\tree.png"))
    panel3.config(image=img9)
    panel3.image=img9
    
    img10=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\fan.png"))
    panel4.config(image=img10)
    panel4.image=img10

    img11=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\bird.png"))
    panel5.config(image=img11)
    panel5.image=img11
    
    b1.config(command=ok2)
    b2.config(command=ref1)
    
def ref1():
    ##third set of images 
    img12=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\chair.png"))
    panel.config(image=img12)
    panel.image=img12
    
    img13=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\horse.png"))
    panel1.config(image=img13)
    panel1.image=img13
    
    img14=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\flower.png"))
    panel2.config(image=img14)
    panel2.image=img14
    
    img15=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\house.png"))
    panel3.config(image=img15)
    panel3.image=img15
    
    img16=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\train.png"))
    panel4.config(image=img16)
    panel4.image=img16

    img17=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\pencil.png"))
    panel5.config(image=img17)
    panel5.image=img17
    
    b1.config(command=ok3)
    b2.config(command=ref2)
    
def ref2():
    ##fourth set of images
    img18=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\computer.png"))
    panel.config(image=img18)
    panel.image=img18
    
    img19=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\table.png"))
    panel1.config(image=img19)
    panel1.image=img19
    
    img20=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\dog.png"))
    panel2.config(image=img20)
    panel2.image=img20
    
    img21=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\telephone.png"))
    panel3.config(image=img21)
    panel3.image=img21
    
    img22=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\moon.png"))
    panel4.config(image=img22)
    panel4.image=img22

    img23=ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\chair.png"))
    panel5.config(image=img23)
    panel5.image=img23
    
    b1.config(command=ok4)
    ##redirecting to second set of images
    b2.config(command=ref)    
    
global h
global b1
global b2
h=Label(padx=60,pady=20,bg='black',fg='lime green')
h.config(text=("KIDS LEARNING GAME"))
h.pack()

b2=Button(main,text='REFRESH',bg='black',fg='lime green',command=ref)
b2.pack(ipady=20,ipadx=45,side="bottom")
b1=Button(main,text='OK',bg='black',fg='lime green',command=ok1)
b1.pack(ipady=20,ipadx=60,side="bottom")

##first set of images 
img = ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\football.png"))
panel = Label(image = img)
panel.pack(side="left")

img1 = ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\lion.png"))
panel1 = Label(image = img1)
panel1.pack(side="left")

img2 = ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\earth.png"))
panel2 = Label(image = img2)
panel2.pack(side="left")

img3 = ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\knife.png"))
panel3 = Label(image = img3)
panel3.pack(side="left")

img4 = ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\snake.png"))
panel4 = Label(image = img4)
panel4.pack(side="left")

img5 = ImageTk.PhotoImage(Image.open("C:\\Users\\HP\\Desktop\\Python project\\Image gallery\\clock.png"))
panel5 = Label(image = img5)
panel5.pack(side="left")

main.mainloop()
